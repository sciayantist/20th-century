# %%
# 01. Install Libraries

# %%
#install install from a “requirements.txt” File
pip install -r requirements.txt
# Out:
#   Cell In[18], line 2
#     pip install -r requirements.txt
#         ^
# SyntaxError: invalid syntax

# %%
pip uninstall pandas
# Out:
# Found existing installation: pandas 2.2.3
# Uninstalling pandas-2.2.3:
#   Would remove:
#     /opt/anaconda3/envs/20th_century/lib/python3.12/site-packages/pandas-2.2.3.dist-info/*
#     /opt/anaconda3/envs/20th_century/lib/python3.12/site-packages/pandas/*
# Proceed (Y/n)?

# %% [markdown]
# # 02. Import libraries and Access web data without API

# %%
# Import libraries

import pandas as pd
import time
from selenium import webdriver
from webdriver_manager.chrome import ChromeDriverManager
from selenium.webdriver.common.by import By
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.chrome.options import Options
import matplotlib.pyplot as plt
import os
import logging
import requests
import bs4

# %% [markdown]
# # 03. Install the driver

# %%
#Install ChromeDriverManager
service  =  Service(executable_path=ChromeDriverManager().install())
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[16], line 2
#       1 #Install ChromeDriverManager
# ----> 2 service  =  Service(executable_path=ChromeDriverManager().install())
#
# File /opt/anaconda3/envs/20th_century/lib/python3.12/site-packages/webdriver_manager/chrome.py:39, in ChromeDriverManager.install(self)
#      38 def install(self) -> str:
# ---> 39     driver_path = self._get_driver_path(self.driver)
#      40     os.chmod(driver_path, 0o755)
#      41     return driver_path
#
# File /opt/anaconda3/envs/20th_century/lib/python3.12/site-packages/webdriver_manager/core/manager.py:30, in DriverManager._get_driver_path(self, driver)
#      27 if binary_path:
#      28     return binary_path
# ---> 30 file = self._download_manager.download_file(driver.get_url())
#      31 binary_path = self.driver_cache.save_file_to_cache(driver, file)
# ...

# %%
#driver = webdriver.Chrome(executable_path=r'C:\Program Files\Google\Chrome\chromedriver.exe')

driver = webdriver.Chrome(executable_path=r'/Users/aya/Desktop/DataAnalytics/Data-Visualizations-with-Python/20th-century/chromedriver_mac64/chromedriver.exe')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# File /opt/anaconda3/envs/20th_century/lib/python3.12/site-packages/selenium/webdriver/common/service.py:72, in Service.start(self)
#      71     cmd.extend(self.command_line_args())
# ---> 72     self.process = subprocess.Popen(cmd, env=self.env,
#      73                                     close_fds=platform.system() != 'Windows',
#      74                                     stdout=self.log_file,
#      75                                     stderr=self.log_file,
#      76                                     stdin=PIPE)
#      77 except TypeError:
#
# ...
