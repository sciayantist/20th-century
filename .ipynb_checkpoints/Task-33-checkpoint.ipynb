# %%
import sys

# %% [markdown]
# # 1. Install Libraries

# %%
#Install Libraries
conda install pandas numpy

# %% [markdown]
# # 02. Importing Libraries

# %%
#Import Libraries
import pandas as pd
import numpy as np

# %% [markdown]
# # 03. Create a Dataset

# %%
#Create a dataframe
animal_data = pd.DataFrame({"Animal Name": ['Monkey', 'Giraffe', 'Tiger', 'Penguin', 'Panda'],
                            "Favorite Foods": ['Bananas', 'Leaves', 'Deer', 'Fish', 'Bamboo'],
                            "Country": ['Egypt','Kenya', 'Russia', 'New Zealand', 'China'],
                            "Age": [ 2, 7, 3, 4, 5]})

# %%
animal_data.head(5)
# Out:
#   Animal Name Favorite Foods      Country  Age
# 0      Monkey        Bananas        Egypt    2
# 1     Giraffe         Leaves        Kenya    7
# 2       Tiger           Deer       Russia    3
# 3     Penguin           Fish  New Zealand    4
# 4       Panda         Bamboo        China    5

# %% [markdown]
# # 04. Use Apply() & Lambda() Functions

# %%
#Create a Triple Age function
def triple_age(row) : 
    return row['Age'] * 3

# %%
#Apply the funtion to the column and save the values in a new column (deriving a variable)
animal_data['triple_Age'] = animal_data.apply(triple_age, axis =1)

# %%
#Check the data
animal_data
# Out:
#   Animal Name Favorite Foods      Country  Age  triple_Age
# 0      Monkey        Bananas        Egypt    2           6
# 1     Giraffe         Leaves        Kenya    7          21
# 2       Tiger           Deer       Russia    3           9
# 3     Penguin           Fish  New Zealand    4          12
# 4       Panda         Bamboo        China    5          15

# %%
#Use Lambda Funstions animal_data
triple_Age_2 = lambda x:(x) * 3

# %%
triple_Age_2
# Out:
# <function __main__.<lambda>(x)>

# %%
#Check the column
triple_Age_2(animal_data['Age'])
# Out:
# 0     6
# 1    21
# 2     9
# 3    12
# 4    15
# Name: Age, dtype: int64

# %%
#Use the lambda funtion and save the values in a new column (deriving a variable)
animal_data['triple_Age_2'] = triple_Age_2(animal_data['Age'])

# %%
#Check the data
animal_data
# Out:
#   Animal Name Favorite Foods      Country  Age  triple_Age  triple_Age_2
# 0      Monkey        Bananas        Egypt    2           6             6
# 1     Giraffe         Leaves        Kenya    7          21            21
# 2       Tiger           Deer       Russia    3           9             9
# 3     Penguin           Fish  New Zealand    4          12            12
# 4       Panda         Bamboo        China    5          15            15

# %%
animal_data.head(5)
# Out:
#   Animal Name Favorite Foods      Country  Age  triple_Age  triple_Age_2
# 0      Monkey        Bananas        Egypt    2           6             6
# 1     Giraffe         Leaves        Kenya    7          21            21
# 2       Tiger           Deer       Russia    3           9             9
# 3     Penguin           Fish  New Zealand    4          12            12
# 4       Panda         Bamboo        China    5          15            15

# %%
#Create a list
Country_Region = {"Egypt":"North Africa",
                  "Kenya":"Africa",
                  "Russia":"Europe",
                  "New Zealand":"Oceania",
                  "China":"Asia"}

# %%
#Check the list
Country_Region
# Out:
# {'Egypt': 'North Africa',
#  'Kenya': 'Africa',
#  'Russia': 'Europe',
#  'New Zealand': 'Oceania',
#  'China': 'Asia'}

# %%
#Create a flag cloumn using lambda (deriving a variable)
animal_data['Region'] = animal_data['Country'].apply(lambda country: Country_Region.get(country))

# %%
#Check the dataframe
animal_data
# Out:
#   Animal Name Favorite Foods      Country  Age  triple_Age  triple_Age_2  \
# 0      Monkey        Bananas        Egypt    2           6             6
# 1     Giraffe         Leaves        Kenya    7          21            21
# 2       Tiger           Deer       Russia    3           9             9
# 3     Penguin           Fish  New Zealand    4          12            12
# 4       Panda         Bamboo        China    5          15            15
#
#          Region
# 0  North Africa
# 1        Africa
# 2        Europe
# 3       Oceania
# 4          Asia

# %%
#Alternative way
#Create a flag cloumn using lambda (deriving a variable)
animal_data['Region_2'] = animal_data['Country'].apply(
    lambda country: (
        'North Africa' if country == 'Egypt' else
        'Africa' if country == 'Kenya' else
        'Oceania' if country == 'New Zealand' else
        'Asia' if country == 'China' else
        'Unknown'))

# %%
#Check the dataframe
animal_data
# Out:
#   Animal Name Favorite Foods      Country  Age  triple_Age  triple_Age_2  \
# 0      Monkey        Bananas        Egypt    2           6             6
# 1     Giraffe         Leaves        Kenya    7          21            21
# 2       Tiger           Deer       Russia    3           9             9
# 3     Penguin           Fish  New Zealand    4          12            12
# 4       Panda         Bamboo        China    5          15            15
#
#          Region      Region_2
# 0  North Africa  North Africa
# 1        Africa        Africa
# 2        Europe       Unknown
# 3       Oceania       Oceania
# 4          Asia          Asia
