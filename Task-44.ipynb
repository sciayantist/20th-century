# %%
conda install pandas numpy
# Out:
# Channels:
#  - conda-forge
#  - bioconda
#  - defaults
# Platform: osx-64
# doneecting package metadata (repodata.json): -
# doneing environment: \
#
# # All requested packages already installed.
#
#
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# # 01. Install Libraries

# %%
#install install from a “requirements.txt” File - **in terminal**
pip install -r requirements.txt

# %% [markdown]
# # 02. Import libraries and Access web data without API

# %%
#Import libraries
import pandas as pd
import time
from selenium import webdriver
from webdriver_manager.chrome import ChromeDriverManager
from selenium.webdriver.common.by import By
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.chrome.options import Options
import matplotlib.pyplot as plt 
import os
import logging

# %% [markdown]
# # 03. Install the driver

# %%
path = ('/usr/local/bin/chromedriver')

# %%
#Install ChromeDriverManager
#service  =  Service(executable_path=ChromeDriverManager().install())

service  =  Service(executable_path=path().install())
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[10], line 4
#       1 #Install ChromeDriverManager
#       2 #service  =  Service(executable_path=ChromeDriverManager().install())
# ----> 4 service  =  Service(executable_path=path().install())
#
# TypeError: 'str' object is not callable

# %%
#driver = webdriver.Chrome(executable_path=r'C:\Program Files\Google\Chrome\chromedriver.exe')

#driver = webdriver.Chrome(executable_path=r'/Users/aya/Desktop/DataAnalytics/Data-Visualizations-with-Python/20th-century/chrome-mac-x64/ChromeDriver/Contents/MacOS/ChromeDriver')

#driver = webdriver.Chrome(executable_path=r'C:\Program Files\Google\Chrome\chromedriver.exe')

#driver = webdriver.Chrome(executable_path = r'/Users/aya/Desktop/DataAnalytics/Data-Visualizations-with-Python/20th-century/chrome-mac-x64')
#driver = webdriver.Chrome(service=service)

#driver = webdriver.Chrome(executable_path = r'/Users/aya/Desktop/DataAnalytics/Data-Visualizations-with-Python/20th-century/chrome-mac-x64/ChromeDriver')


driver = webdriver.Chrome(executable_path = r'/Users/aya/Desktop/DataAnalytics/Data-Visualizations-with-Python/20th-century/chrome-mac-x64/ChromeDriver/Contents/MacOS/ChromeTesting')
# Out:
# ---------------------------------------------------------------------------
# WebDriverException                        Traceback (most recent call last)
# Cell In[40], line 13
#       1 #driver = webdriver.Chrome(executable_path=r'C:\Program Files\Google\Chrome\chromedriver.exe')
#       2
#       3 #driver = webdriver.Chrome(executable_path=r'/Users/aya/Desktop/DataAnalytics/Data-Visualizations-with-Python/20th-century/chrome-mac-x64/ChromeDriver/Contents/MacOS/ChromeDriver')
#    (...)
#       9
#      10 #driver = webdriver.Chrome(executable_path = r'/Users/aya/Desktop/DataAnalytics/Data-Visualizations-with-Python/20th-century/chrome-mac-x64/ChromeDriver')
# ---> 13 driver = webdriver.Chrome(executable_path = r'/Users/aya/Desktop/DataAnalytics/Data-Visualizations-with-Python/20th-century/chrome-mac-x64/ChromeDriver/Contents/MacOS/ChromeTesting')
#
# ...
